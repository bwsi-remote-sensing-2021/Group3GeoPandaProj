# %%
import pandas as pd
import matplotlib
import geopandas as gpd
import contextily as ctx # for basemaps
from shapely.geometry import Point, LineString, Polygon
from matplotlib import pyplot as plt

url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-12/volcano.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#      volcano_number              volcano_name primary_volcano_type  \
# 0            283001                       Abu            Shield(s)
# 1            355096                Acamarachi        Stratovolcano
# 2            342080                Acatenango    Stratovolcano(es)
# 3            213004           Acigol-Nevsehir              Caldera
# 4            321040                     Adams        Stratovolcano
# ..              ...                       ...                  ...
# 953          300242                    Zimina    Stratovolcano(es)
# 954          341061  Zitacuaro-Valle de Bravo              Caldera
# 955          221020              Zubair Group               Shield
# 956          221021                     Zukur               Shield
# 957          327120              Zuni-Bandera       Volcanic field
#
#     last_eruption_year        country                          region  \
# 0                -6850          Japan         Japan, Taiwan, Marianas
# ...

# %%
ax = df.plot(x="longitude", y="latitude", kind="scatter", figsize=(10,5), alpha=0.6, c='population_within_10_km', norm=matplotlib.colors.LogNorm())
ctx.add_basemap(ax, crs=df.crs, source=ctx.providers.Stamen.Watercolor)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-e38e7b0d3b8d> in <module>
#       1 ax = df.plot(x="longitude", y="latitude", kind="scatter", figsize=(10,5), alpha=0.6, c='population_within_10_km', norm=matplotlib.colors.LogNorm())
# ----> 2 ctx.add_basemap(ax, crs=df.crs, source=ctx.providers.Stamen.Watercolor)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'crs'
